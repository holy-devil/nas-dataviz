# %%
import pandas as pd
import numpy as np

# %%
nas_full = pd.read_csv('../datasets/nas/nas-pupil-marks.csv');

# trimming all whitespaces from cells
df_obj = nas_full.select_dtypes(['object'])
nas_full[df_obj.columns] = df_obj.apply(lambda x: x.str.strip())

nas_full.iloc[:,:]
# Out:
#               STUID State  District  Gender  Age  Category  Same language  \
# 0       11011001001    AP         1       1    3         3              1
# 1       11011001002    AP         1       2    3         4              2
# 2       11011001003    AP         1       2    3         4              2
# 3       11011001004    AP         1       2    3         3              2
# 4       11011001005    AP         1       2    3         3              2
# 5       11011001006    AP         1       2    3         3              1
# 6       11011001007    AP         1       2    3         4              2
# 7       11011001008    AP         1       2    2         0              2
# 8       11011001009    AP         1       2    3         3              2
# 9       11011001010    AP         1       2    2         4              2
# 10      11011001012    AP         1       2    3         3              2
# 11      11011001013    AP         1       2    5         3              2
# ...

# %%
nas_full.tail()
# Out:
#               STUID State  District  Gender  Age  Category  Same language  \
# 185343  45021031048    DD         2       2    3         3              1
# 185344  45021031049    DD         2       2    2         1              1
# 185345  45021031050    DD         2       2    3         2              1
# 185346  45021031051    DD         2       2    3         2              1
# 185347  45021031052    DD         2       2    3         2              1
#
#         Siblings  Handicap  Father edu    ...     Express science views  \
# 185343         2         2           3    ...                         2
# 185344         3         2           3    ...                         2
# 185345         3         2           3    ...                         2
# 185346         2         2           1    ...                         2
# 185347         2         2           1    ...                         2
#
#         Watch TV  Read magazine  Read a book  Play games Help in household  \
# ...

# %%
# Counting size of dataset
nas_full.count
# Out:
# <bound method DataFrame.count of               STUID State  District  Gender  Age  Category  Same language  \
# 0       11011001001    AP         1       1    3         3              1
# 1       11011001002    AP         1       2    3         4              2
# 2       11011001003    AP         1       2    3         4              2
# 3       11011001004    AP         1       2    3         3              2
# 4       11011001005    AP         1       2    3         3              2
# 5       11011001006    AP         1       2    3         3              1
# 6       11011001007    AP         1       2    3         4              2
# 7       11011001008    AP         1       2    2         0              2
# 8       11011001009    AP         1       2    3         3              2
# 9       11011001010    AP         1       2    2         4              2
# 10      11011001012    AP         1       2    3         3              2
# ...

# %%
# Checkhing for duplicates
#678 rows found
stuid = nas_full['STUID']
nas_full[stuid.isin(stuid[stuid.duplicated()])].sort('STUID')
# Out:
# e:\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#               STUID State  District  Gender  Age  Category  Same language  \
# 36      11011002001    AP         1       2    3         3              1
# 37      11011002001    AP         1       2    3         3              1
# 206     11011008022    AP         1       1    3         4              1
# 207     11011008022    AP         1       1    3         4              1
# 548     11011020006    AP         1       2    3         2              2
# 549     11011020006    AP         1       2    3         2              2
# 552     11011020009    AP         1       2    2         4              1
# 553     11011020009    AP         1       2    2         4              1
# 590     11011022023    AP         1       2    1         3              1
# 591     11011022023    AP         1       2    1         3              1
# ...

# %% [markdown]
# ## Removing 678 duplicate rows

# %%
df1 = nas_full.drop_duplicates(subset=['STUID'], keep=False)
df1 
# Removed duplicate student ID
# Out:
#               STUID State  District  Gender  Age  Category  Same language  \
# 0       11011001001    AP         1       1    3         3              1
# 1       11011001002    AP         1       2    3         4              2
# 2       11011001003    AP         1       2    3         4              2
# 3       11011001004    AP         1       2    3         3              2
# 4       11011001005    AP         1       2    3         3              2
# 5       11011001006    AP         1       2    3         3              1
# 6       11011001007    AP         1       2    3         4              2
# 7       11011001008    AP         1       2    2         0              2
# 8       11011001009    AP         1       2    3         3              2
# 9       11011001010    AP         1       2    2         4              2
# 10      11011001012    AP         1       2    3         3              2
# 11      11011001013    AP         1       2    5         3              2
# ...

# %% [markdown]
# ## Checking data meanings using column labels
